# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
l = 8
w = 10
h = 5
d = 0.5

x, y = zip(*np.array([[0,0], [l/3,0], [l/3,d], [2*l/3,d], [2*l/3,0], [l,0], [l,w/3], [l-d,w/3], [l-d,2*w/3], [l,2*w/3], [l,w], [2*l/3,w], [2*l/3,w-d], [l/3,w-d], [l/3,w], [0,w], [0,2*w/3], [d,2*w/3], [d,w/3], [0,w/3], [0,0]]))

plt.plot(x, y)
plt.axis('equal')
plt.title('Box Scale [mm]')
plt.show()

# %%
x, y = zip(*np.array([[0,d], [l/3,d], [l/3,0], [2*l/3,0], [2*l/3,d], [l-d,d], [l-d,h/3], [l,h/3], [l,2*h/3], [l-d,2*h/3], [l-d,h-d], [2*l/3,h-d], [2*l/3,h], [l/3,h], [l/3,h-d], [0,h-d], [0,2*h/3], [d,2*h/3], [d,h/3], [0,h/3], [0,d]]))

plt.plot(x, y)
plt.axis('equal')
plt.title('Box Scale [mm]')
plt.show()

# %%
x, y = zip(*np.array([[0,d], [w/3,d], [w/3,0], [2*w/3,0], [2*w/3,d], [w-d,d], [w-d,h/3], [w,h/3], [w,2*h/3], [w-d,2*h/3], [w-d,h-d], [2*w/3,h-d], [2*w/3,h], [w/3,h], [w/3,h-d], [0,h-d], [0,2*h/3], [d,2*h/3], [d,h/3], [0,h/3], [0,d]]))

plt.plot(x, y)
plt.axis('equal')
plt.title('Box Scale [mm]')
plt.show()

# %%
f, axarr = plt.subplots(3, sharex=True, sharey=True, figsize=(8,8))

x, y = zip(*np.array([[0,0], [l/3,0], [l/3,d], [2*l/3,d], [2*l/3,0], [l,0], [l,w/3], [l-d,w/3], [l-d,2*w/3], [l,2*w/3], [l,w], [2*l/3,w], [2*l/3,w-d], [l/3,w-d], [l/3,w], [0,w], [0,2*w/3], [d,2*w/3], [d,w/3], [0,w/3], [0,0]]))
axarr[0].plot(x, y)

x, y = zip(*np.array([[0,d], [l/3,d], [l/3,0], [2*l/3,0], [2*l/3,d], [l-d,d], [l-d,h/3], [l,h/3], [l,2*h/3], [l-d,2*h/3], [l-d,h-d], [2*l/3,h-d], [2*l/3,h], [l/3,h], [l/3,h-d], [0,h-d], [0,2*h/3], [d,2*h/3], [d,h/3], [0,h/3], [0,d]]))
axarr[1].plot(x, y)

x, y = zip(*np.array([[0,d], [w/3,d], [w/3,0], [2*w/3,0], [2*w/3,d], [w-d,d], [w-d,h/3], [w,h/3], [w,2*h/3], [w-d,2*h/3], [w-d,h-d], [2*w/3,h-d], [2*w/3,h], [w/3,h], [w/3,h-d], [0,h-d], [0,2*h/3], [d,2*h/3], [d,h/3], [0,h/3], [0,d]]))
axarr[2].plot(x, y)
plt.axis('equal')
plt.show()

# %% [markdown]
# Makercase bietet dies schon an.
